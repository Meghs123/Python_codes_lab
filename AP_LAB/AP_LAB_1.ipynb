# %%
print("Google")
# Out:
# Google

# %%
print("Megha Singh")
# Out:
# Megha Singh

# %%
a="Megha"
print(a)
print(type(a))
# Out:
# Megha
# <class 'str'>

# %%
b=455
print(b)
print(type(b))
# Out:
# 455
# <class 'int'>

# %%
b=455.78
print(b)
print(type(b))
# Out:
# 455.78
# <class 'float'>

# %%
t="My 'India' is best"
print(t)
# Out:
# My 'India' is best

# %%
p="Hello \"World\""
print(p)
# Out:
# Hello "World"

# %%
p="Hello \"World\""
t='''My 'India' is best
     We love our India'''
print(t)
print(type(t))
# Out:
# My 'India' is best
#      We love our India
# <class 'str'>

# %%
di=True
d2=False
d3=None
print(di)
print(d2)
print(d3)
# Out:
# True
# False
# None

# %% [markdown]
# AP LAB 2 (ASSIGNMENT 2)

# %%
#Q1
di=True
d2=False
print(di and d2)
# Out:
# False

# %%
di=True
d2=True
print(di and d2)
# Out:
# True

# %%
di=False
d2=False
print(di and d2)
# Out:
# False

# %%
di=False
d2=True
print(di and d2)
# Out:
# False

# %% [markdown]
# OR

# %%
#Q2
di=True
d2=False
print(di or d2)
# Out:
# True

# %%
di=True
d2=True
print(di or d2)
# Out:
# True

# %%
di=False
d2=False
print(di or d2)
# Out:
# False

# %%
di=False
d2=True
print(di or d2)
# Out:
# True

# %% [markdown]
# NOT

# %%
#Q3
di=False
print(not di)
# Out:
# True

# %%
di=True
print(not di)
# Out:
# False

# %%
#Q4
print("*")
print("* *")
print("* * *")
print("* * * *")
print("* * * * *")
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
#Q4
t='''
     *
     * *
     * * *
     * * * *
     * * * * *'''
print(t)
# Out:
#      *
#      * *
#      * * *
#      * * * *
#      * * * * *

# %%
#Q5
print("     *  ")
print("    * *  ")
print("   * * *  ")
print("  * * * *  ")
print(" * * * * *  ")
# Out:
#      *
#     * *
#    * * *
#   * * * *
#  * * * * *

# %%
#Q6
print("         *")
print("       * *")
print("     * * *")
print("   * * * *")
print(" * * * * *")
# Out:
#          *
#        * *
#      * * *
#    * * * *
#  * * * * *

# %%
#Combine of Q1 ,Q2 and Q3
x=True
y=False
print(x and y)
print(x or y)
print(not x)
print(not y)
# Out:
# False
# True
# False
# True
