# %%
a="megha singh"
print(len(a))
print(a.endswith("singh")) #last word same with given sentence
print(a.endswith("singhania"))
print(a)
print(a.count("i"))
print(a.count("I"))
print(a.capitalize())   #preprocessor
print(a.find("singh"))
print(a.find("hello"))  #when you dont find the word it will return -1
print(a.replace("megha","akansksha"))
# Out:
# 11
# True
# False
# megha singh
# 1
# 0
# Megha singh
# 6
# -1
# akansksha singh

# %% [markdown]
# escape sequence character

# %%
 a="I am from India. \'I love India"
 print(a)
# Out:
# I am from India. 'I love India

# %% [markdown]
# ##AP_LAB_5
#
# Q.1) Write a python program to count the total no. of characters of a given string without space.

# %%
s="Hello people"
n=len(s)-s.count(" ")
print(n)
# Out:
# 11

# %% [markdown]
# Q.2) Write a python program to check whether a sentence ends with a specific word or not?

# %%
s="I am from India"
print(s.endswith("India"))
# Out:
# True

# %% [markdown]
# Q.3) Write a python program to check the frequency of a specific character and a specific word within a string.

# %%
s="I am from India"
print(s.count("I"))
print(s.count("from"))
# Out:
# 2
# 1

# %% [markdown]
# Q.4) Write a python program to find the position of a specific word in the given string.

# %%
s="I am from India"
print(s.find("India"))
# Out:
# 10

# %% [markdown]
# Q.5) Write a python program to replace an existing sub-string of a string with a new string.

# %%
s="I am from India"
print(s.replace("India","Australia"))
# Out:
# I am from Australia

# %% [markdown]
# Q.6) Write a python program to display a sub-string of a string with single quote (‘). Also specify the tab space and new line.

# %%
s="\'Good' morning \t students.\n Welcom to the class."
print(s)
# Out:
# 'Good' morning 	 students.
#  Welcom to the class.

# %% [markdown]
# Q.7) Write a python program to capitalize the 1st letter of each and every word of a string.

# %%
s="Welcome to this world."
print(s.title())
# Out:
# Welcome To This World.
